# %%
from conn_unzip import *
from conn_manage import *

# %%
# GET NEW CONNECTIONS
get_new_connections()
# Out:
# Succesfuly unziped instagram-elicarriedo-2025-02-22-pizmP1ne.zip

# %%
check_followers()
# Out:
# > Followers: 386 (0)
# > New unfollowers up-to-date!
# > Last 5 old unfollowers:
#   - therealmikedean - Following
#   - borisbrejcha - Following
#   - patriciosardelli - Following
#   - airbag.oficial - Following
#   - basic.blanks - Following
# > New followers up-to-date!
# > Last 5 old followers:
#   - magaapamo
#   - rrogauna
#   - __carriedont__
#   - juli.laurido
#   - cromatica.ds
#
# Followers saved succesfully!
# Unfollowers saved succesfully!

# %%
check_following()
# Out:
# > Following: 344 (0)
# > New following users up-to-date!
# > Last 5 old following users:
#   - magaapamo
#   - rrogauna
#   - solcito.bini
#   - therealmikedean
#   - juli.laurido
#
# Following users saved succesfully!

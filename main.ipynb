# %%
from conn_unzip import *
from conn_manage import *

# %%
# GET NEW CONNECTIONS
get_new_connections()
# Out:
# Succesfuly unziped instagram-elicarriedo-2025-02-22-pizmP1ne.zip

# %%
check_followers()
# Out:
# Followers: 386
#
#
# New unfollowers up-to-date!
#
# Last 5 old unfollowers:
# - therealmikedean - Following
# - borisbrejcha - Following
# - patriciosardelli - Following
# - airbag.oficial - Following
# - basic.blanks - Following
# - f1 - Following
# - francolapinto - Following
# - lukadoncic - Following
# - exepalaciosok - Following
# - elementsba - Following
# - felitamburri - Following
# - uba_ar - Following
# - evolve__ba - Following
# - mirage.prods - Following
# - lollapaloozaar - Following
# - hermesonori - Following
# - proyectosuplemento - Following
# - shato.tm - Following
# - djhernancattaneo - Following
# - agentsoftime - Following
# - near.applestore - Following
# - guardavidasymcacaba - Following
# - muni_pinamar - Following
# - nicodelacruz10 - Following
# - beltranlucass - Following
# - nicki.nicole - Following
# - angeldimariajm - Following
# - claudioecheverri_ - Following
# - gero.duna - Following
# - gonzalo_montiel29 - Following
# - espnargentina - Following
# ...

# %%
check_following()
